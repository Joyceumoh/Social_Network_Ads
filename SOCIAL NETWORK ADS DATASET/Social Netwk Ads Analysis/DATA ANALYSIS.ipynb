# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("Social_Network_Ads.csv", sep=',')

# %%
data=data.drop(['User ID', 'Gender'], axis=1)
data
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
# There are 400 rows and 3 columns in the dataset

# %%
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
# The first 5 rows of the dataset

# %%
data.tail()
# Out:
#      Age  EstimatedSalary  Purchased
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1

# %%
# The last 5 rows of the dataset

# %%
data.info
# Out:
# <bound method DataFrame.info of      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]>

# %%
# information about the dataset

# %%
data.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
# There are no bars on the chart because there are no null values on the columns in the dataset

# %%
data[['Age']]
# Out:
#      Age
# 0     19
# 1     35
# 2     26
# 3     27
# 4     19
# ..   ...
# 395   46
# 396   51
# 397   50
# 398   36
# 399   49
#
# [400 rows x 1 columns]

# %%
# The age of persons in the dataset

# %%
above_30=data['Age']>30
below_30, above_30=data[~above_30], data[above_30]
above_30
# Out:
#      Age  EstimatedSalary  Purchased
# 1     35            20000          0
# 7     32           150000          1
# 9     35            65000          0
# 13    32            18000          0
# 16    47            25000          1
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [289 rows x 3 columns]

# %%
# There are 289 persons above 30 years old in the dataset

# %%
not_purchased=data['Purchased']==0
purchased, not_purchased=data[~not_purchased], data[not_purchased]
purchased.describe()
# Out:
#               Age  EstimatedSalary  Purchased
# count  143.000000       143.000000      143.0
# mean    46.391608     86272.727273        1.0
# std      8.612172     42064.200064        0.0
# min     27.000000     20000.000000        1.0
# 25%     39.500000     41000.000000        1.0
# 50%     47.000000     90000.000000        1.0
# 75%     53.000000    122500.000000        1.0
# max     60.000000    150000.000000        1.0

# %%
# 143 persons purchased the Ads

# %%
not_purchased.describe()
# Out:
#               Age  EstimatedSalary  Purchased
# count  257.000000       257.000000      257.0
# mean    32.793774     60544.747082        0.0
# std      7.985844     24351.570102        0.0
# min     18.000000     15000.000000        0.0
# 25%     26.000000     44000.000000        0.0
# 50%     34.000000     61000.000000        0.0
# 75%     38.000000     77000.000000        0.0
# max     59.000000    141000.000000        0.0

# %%
# 257 persons did not purchase the Ads

# %%
data.nunique()
# Out:
# Age                 43
# EstimatedSalary    117
# Purchased            2
# dtype: int64

# %%
# There are 43 unique values in Age column
# There are 117 unique values in EstimatedSalary column
# There are 2 unique values in Purchased column

# %%
data[['Age']].describe()
# Out:
#               Age
# count  400.000000
# mean    37.655000
# std     10.482877
# min     18.000000
# 25%     29.750000
# 50%     37.000000
# 75%     46.000000
# max     60.000000

# %%
# Mean Age is 37
# Maximum Age is 60
# Minimum Age is 18

# %%
data["Purchased"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
# Persons that did not purchase the Ads are more than persons that purchased the Ads

# %%
purchase_counts = data['Purchased'].value_counts()
print('Purchase Counts:\n', purchase_counts)
# Out:
# Purchase Counts:
#  0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
# 143 persons made a purchase
# 257 persons did not make a purchase

# %%
percentage_purchase = (purchase_counts[1] / purchase_counts.sum()) * 100
print(f'Percentage of people who made a purchase: {percentage_purchase:.2f}%')
# Out:
# Percentage of people who made a purchase: 35.75%

# %%
# Overall percentage of persons who made a purchase is 35.75%

# %% [markdown]
# # UNIVARIATE EXPLORATION

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data['Age'], bins=5)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Persons from 35 to 42 years old have the highest frequency in the dataset

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data['EstimatedSalary'], bins=5)
plt.title('Estimated Salary Distribution')
plt.xlabel('Estimated Salary')
plt.ylabel('Frequency')
plt.show()

# %%
# Estimated salary from 70,000 to 95,000 have the highest frequency in the dataset

# %%
# Histograms to visualize distributions
plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.hist(data['Purchased'], bins=2, color='purple', alpha=1)
plt.title('Purchased Distribution')
plt.xlabel('Purchased')
# Out:
# Text(0.5, 0, 'Purchased')

# %%
# People who did not purchase are more than those who purchase

# %% [markdown]
# # BIVARIATE EXPLORATION

# %%
sns.scatterplot(x='Age', y='Purchased', data=data)
plt.title('Purchased vs Age')
plt.show()

# %%
# There is correlation between purchased and the ages of people who purchased

# %%
sns.scatterplot(x='EstimatedSalary', y='Purchased', data=data)
plt.title('Purchased vs EstimatedSalary')
plt.show()

# %%
# There's relationship between those who puchased and their estimated salaries

# %%
sns.scatterplot(x='Age', y='EstimatedSalary', data=data)
plt.title('EstimatedSalary vs Age')
plt.show()

# %%
sns.boxplot(x='Purchased', y='Age', data=data)
plt.title('Age vs. Purchase')
plt.show()

# %%
# Persons from 17 to 38 years old did not make a purchase
# Persons from 41 to 60 years old made a purchase

# %%
sns.boxplot(x='Purchased', y='EstimatedSalary', data=data)
plt.title('Estimated Salary vs. Purchased')
plt.show()

# %%
# Persons earning 15,000 to 77,000 did not make a purchase
# Persons earning 41,000 to 150,000 made a purchase

# %%
sns.kdeplot(data[data['Purchased'] == 1]['EstimatedSalary'], label='Purchased')
sns.kdeplot(data[data['Purchased'] == 0]['EstimatedSalary'], label='Not Purchased')
plt.title('Estimated Salary Distribution')
plt.xlabel('Estimated Salary')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
# Persons who made a purchase earn more salary than those who did not make a purchase.

# %%
sns.boxplot(data=data[['Age', 'EstimatedSalary']])
plt.title('Boxplot of Age and Estimated Salary')
plt.show()

# %%
# There are no outliers in Age and EstimatedSalary columns and this means that no value in the columns are above the mean values
# It also means that there is no bias

# %% [markdown]
# # Multivariate Exploration

# %%
corr_matrix=data.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='viridis',)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Age column has more relationship (62%) with Purchased column compared to EstimatedSalary (36%)

# %%
# Pairplot to visualize relationships between all variables
sns.pairplot(data)

# %%
# The above pairplot shows that Age has a relationship with Purchased

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data['Age'], data['EstimatedSalary'], data['Purchased'], c='r', marker=0)
ax.set_xlabel('Age')
ax.set_ylabel('EstimatedSalary')
ax.set_zlabel('Purchased')
plt.title('3D Scatter Plot of Age, EstimatedSalary and Purchased')
# Out:
# Text(0.5, 0.92, '3D Scatter Plot of Age, EstimatedSalary and Purchased')

# %%
# This shows that there's a relationship between Age, EstimatedSalary and those who purchased.
